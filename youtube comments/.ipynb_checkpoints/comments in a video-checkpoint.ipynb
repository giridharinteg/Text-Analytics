# %%
import datetime
import pandas as pd
import copy
from datetime import timedelta
import os
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from time import sleep

# %%
quota={"used":0,"pending":10000}
video_id = "ahZFCF--uRY"
api_keys=["AIzaSyDKqdDYtWgMXnRdlyulXGkjbk5XFcAmtOo"]
#["AIzaSyAbBOXIKVuAM3rOGFNatUpgLUXVEG11V4w", 
 #         "AIzaSyDQNRqg_IKzd5i9UFPBAYqjQW7kspgWTNM", 
#         "AIzaSyDqiK5SG8cfeARoLiAHUyVHioNVwa-KpQM",
 #         "AIzaSyB097byPzSwdcp9SvsPsola9iQMAg1ScLM"]

# %%
def YT_get_authenticated_service(jsonfile = None,api_key = None):
    if(jsonfile == None and api_key == None):
        raise WRONG_KEY_ERROR('Either pass a json client file or pass api key as input to either jsonfile = or api_key =')
    API_SERVICE_NAME = 'youtube'
    API_VERSION = 'v3'
    developerKey=DEVELOPER_KEY = api_key
    return build(API_SERVICE_NAME, API_VERSION, developerKey=DEVELOPER_KEY)


YT = YT_get_authenticated_service(api_key = api_keys.pop())

# %%
def YT_get_comments_in_video(
                            video_id,
                            part             = 'snippet',
                            #order            = 'date',
                            #published_after  = '2018-01-01T00:00:00Z', 
                            #published_before = '2018-09-01T00:00:00Z', 
                            #category_id     = '26',
                            #topic_id        = '/m/032tl|/m/041xxh',
                            #fields = 'etag,eventId,items(id(channelId,playlistId,videoId)),kind,nextPageToken,pageInfo,prevPageToken,regionCode,tokenPagination,visitorId',
                            next_page_id = ''
                            ):
    need_more = True
    op_list = []
    #df = pd.DataFrame(columns = ["videoId","view","like","dislike","comments","favourite"])
    while(need_more):
        result = YT.commentThreads().list(
          part            = part,
          videoId         = video_id,
          maxResults      = 100,
          #videoCategoryId = category_id,
          textFormat      = "plainText",
          #order           = order,
          #publishedAfter  = published_after,
          #publishedBefore = published_before,
          #type            = 'video',
          pageToken       = next_page_id,
          #fields          = fields
                                ).execute()
        quota["used"] += 100
        quota["pending"] -= 100
        try:
            next_page_id = result["nextPageToken"]
        except:
            next_page_id = "last page"
            need_more = False
        print(result["pageInfo"])
        print(next_page_id)
        result_items = result["items"]
        for comments in result_items:
            op_list.append(comments)
        
    df = pd.DataFrame(op_list)
    return df

# %%
df_final = YT_get_comments_in_video(video_id)
# Out:
# {'totalResults': 100, 'resultsPerPage': 100}
# QURTSl9pM3Vld0dUdkVVN0x3aW5Ia0RXU2pRakdDbldaWEZ6Q3BhMzd6dXhTRUdGc3pKaXJPM2JqQTJCRmpqWFNMbWUzTmJUNG11MXl3bk1FY01IVmtXcFp5aG00NzVvVHZybDIxRWdIZVRxZm9FdHMzY3o5SmV3UF9mUkV0R0lWaVU=
# {'totalResults': 100, 'resultsPerPage': 100}
# QURTSl9pMGJCemM3dUFFWnpzOWRaNUowX2xiSnE0aHdVNm5XV3pYcFBneVN4ZUZkNUdqekhVNTYwNHJBZkxaN25teDZHN0xNR0htUjVoOGctZTZ5OXpUb2pZUHd3T3VLbDV0RjE1T0V3d0pDYXZGb0FfZ0NzNlhQRVMwdEw4RkdGREpNTHk3QUZ2QThQX2VfOHc=
# {'totalResults': 100, 'resultsPerPage': 100}
# QURTSl9pMjRDTkdQaURFcDhfMm9aV1RrMHpjUWZrdkpHbFNBaUxzaVcwRmlUb1NlZU9oM18yeTl0bnV3TjlwcGNxUmJVN3owTEhYX3pxNHNncXptVW82YjJ6aVNaYVlwMWRUV2N6T1ZWenFvMnBPUWV2ZDlUSGcxNVN2TVNtN19CMXRhRjR6X193aU1oLXNLcFE=
# {'totalResults': 100, 'resultsPerPage': 100}
# QURTSl9pMG5JcHhSTEctZlFzQ3Y4RG9Pd05QbzUwWXdxUi1mUzBsTWZYaFZhYnlZVlFyeGRoa0dwYVR3OGt6WXNwWmNpYlVINUdzMVdYRkpFTExUd21HR0hHSGdGU0NnOU01c0ZRQjRjS196dnpRemlJTmNEcjVIeENFOFBHUmZFeEkzVlNoNVFXQjRveE9DYmc=
# ...

# %%
df_final.head()
# Out:
#                                                 etag  \
# 0  "Fznwjl6JEQdo1MGvHOGaz_YanRU/_Son0PtKnea3lfHDf...
# 1  "Fznwjl6JEQdo1MGvHOGaz_YanRU/a78q1ldF_PKpl--qr...
# 2  "Fznwjl6JEQdo1MGvHOGaz_YanRU/jMHHa1nH-1f3ucb1T...
# 3  "Fznwjl6JEQdo1MGvHOGaz_YanRU/JA06eWCAwHx10eUDP...
# 4  "Fznwjl6JEQdo1MGvHOGaz_YanRU/Spn_cLs5UtqkXIgPx...
#
#                            id                   kind  \
# 0  Ugwg9NXp0eXb8k4WMDR4AaABAg  youtube#commentThread
# 1  UgxlEjcT_AhX6Dmeijl4AaABAg  youtube#commentThread
# 2  UgxQWBL0seaOV9CPaIR4AaABAg  youtube#commentThread
# 3  Ugzwojt7s54KS4olkOx4AaABAg  youtube#commentThread
# 4  UgwbPIPaACKMoa9qErt4AaABAg  youtube#commentThread
#
#                                              snippet
# 0  {'videoId': 'ahZFCF--uRY', 'topLevelComment': ...
# 1  {'videoId': 'ahZFCF--uRY', 'topLevelComment': ...
# 2  {'videoId': 'ahZFCF--uRY', 'topLevelComment': ...
# 3  {'videoId': 'ahZFCF--uRY', 'topLevelComment': ...
# 4  {'videoId': 'ahZFCF--uRY', 'topLevelComment': ...

# %%
df_final.shape
# Out:
# (24485, 4)

# %%
df_final['snippet'][0]['topLevelComment']
#id
#'snippet'.'authorChannelUrl'
#snippet.'authorDisplayName'
#snippet.'authorProfileImageUrl'
#snippet.'likeCount'
#snippet.'publishedAt'
#snippet.'textOriginal'
#snippet.'textDisplay'
#snippet.'videoId'
#snippet.'viewerRating'
# Out:
# {'etag': '"Fznwjl6JEQdo1MGvHOGaz_YanRU/tscD-7wVCw1VoWIeY1ewPhw6LIg"',
#  'id': 'Ugwg9NXp0eXb8k4WMDR4AaABAg',
#  'kind': 'youtube#comment',
#  'snippet': {'authorChannelId': {'value': 'UCQIVQj9syG3GuPkv8FQ-pIw'},
#   'authorChannelUrl': 'http://www.youtube.com/channel/UCQIVQj9syG3GuPkv8FQ-pIw',
#   'authorDisplayName': 'THE ANDROID GUY',
#   'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AGF-l7_3gR0fpu3NlnzONYUVrDx08LwGhtZaK9aOUA=s48-c-k-c0xffffffff-no-rj-mo',
#   'canRate': True,
#   'likeCount': 1,
#   'publishedAt': '2020-01-24T10:27:00.000Z',
#   'textDisplay': 'The biggest success behind this movie is Finn Wolf XD',
#   'textOriginal': 'The biggest success behind this movie is Finn Wolf XD',
#   'updatedAt': '2020-01-24T10:27:00.000Z',
#   'videoId': 'ahZFCF--uRY',
#   'viewerRating': 'none'}}

# %%
final_list = []

# %%
for dictionari in df_final['snippet']:
    commentlevel = {}
    commentlevel["id"] = dictionari['topLevelComment']['id']
    commentlevel["authorChannelUrl"] = dictionari['topLevelComment']['snippet']['authorChannelUrl']
    commentlevel["authorProfileImageUrl"] = dictionari['topLevelComment']['snippet']['authorProfileImageUrl']
    commentlevel["likeCount"] = dictionari['topLevelComment']['snippet']['likeCount']
    commentlevel["publishedAt"] = dictionari['topLevelComment']['snippet']['publishedAt']
    commentlevel["authorDisplayName"] = dictionari['topLevelComment']['snippet']['authorDisplayName']
    commentlevel["textOriginal"] = dictionari['topLevelComment']['snippet']['textOriginal']
    commentlevel["textDisplay"] = dictionari['topLevelComment']['snippet']['textDisplay']
    commentlevel["videoId"] = dictionari['topLevelComment']['snippet']['videoId']
    commentlevel["viewerRating"] = dictionari['topLevelComment']['snippet']['viewerRating']
    final_list.append(commentlevel.copy())

# %%
final_list[1]
# Out:
# {'authorChannelUrl': 'http://www.youtube.com/channel/UCyGnrC9gsDIFa5GQNmItKDg',
#  'authorDisplayName': 'Andy of Avalon',
#  'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AGF-l78WBLEgaMXrli-v0jk2U88p9P6kXvF9zBWB2g=s48-c-k-c0xffffffff-no-rj-mo',
#  'id': 'UgxlEjcT_AhX6Dmeijl4AaABAg',
#  'likeCount': 0,
#  'publishedAt': '2020-01-24T06:33:45.000Z',
#  'textDisplay': "Finally Ghostbusters 3. I was in the queues with my Dad at 11 pm for Ghostbusters 2 at the cinema. \nMy Dad let me stay up waaaay past my bedtime on release day because he wanted to watch it with me.\nFirst film I remember was on my Dads lap at a drive in for Empire Strikes Back (I think I was 2).\nRIP Dad, I am glad you aren't around to see what they did to our memories.",
# ...

# %%
len(final_list)
# Out:
# 24485

# %%
final_df = pd.DataFrame(final_list)

# %%
final_df.shape
# Out:
# (24485, 10)

# %%
final_df.to_excel('comments2.xlsx')
